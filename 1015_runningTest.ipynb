# %%
import cerebDB

# %%
cereb = cerebDB.CerebDB_Generator('backupdb_1015.db')
# Out:
# => Importing DB from 'backupdb_1015.db'. table : paper, link
# Success. Now we have '333,205 papers' and '680,362 links'.
# - papers : ['p_id', 'doi', 'arxiv_id', 'ieee_id', 'uid', 'scp_id', 'scp_eid', 'issn', 'title', 'authors', 'abstract', 'keywords', 'pub_year', 'version', 'start_date', 'end_date', 'subtype', 'aggtype', 'bibtext', 'n_cite', 'n_ref', 'publisher', 'publication', 'vol', 'issue', 'pages', 'affiliation', 'headings', 'subheadings', 'subjects', 'refers', 'citations', 'last_update']
# - links : ['p_id_is_cited', 'by_p_id', 'cite_text']
#
# => Cleansing and extracting representative values of papers..
# Done.
#           p_id                          title                       abstract  \
# 0       217695  Delayed fluorescence as a ...  The plant circadian clock ...
# 1       217697  MYB-FL controls gain and l...  © 2016 Nature America, Inc...
# 2       217699  Multicolor fluorescence im...  © 2016 Pérez-Bueno, Pineda...
# ...
